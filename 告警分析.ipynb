# %%
import pandas as pd
data = pd.read_excel("clustered.xlsx")

# %%
LLM_API_KEY = "aaa16e53a2cf92220d4fd3d9282a9fa7.A8zR3KN6eI1uKwZM"
LLM_MODEL = "glm-4-long"
# 官方正确导入
from zhipuai import ZhipuAI

# 官方客户端，无任何BUG
client = ZhipuAI(api_key=LLM_API_KEY)

# %%
ls=[{'cluster_id': 0, 'alert_count': 30, 'service': 'dbservice1', 'level': 'INFO', 'first_time': '2021-08-01 03:11:19,709', 'last_time': '2021-08-01 04:00:07,980', 'sample_content': ['upload business logs on 2021-07-31 successfully', 'upload trace logs on 2021-07-31 successfully', 'upload run_logs logs on 2021-07-31 successfully']}, {'cluster_id': 1, 'alert_count': 27, 'service': 'dbservice1', 'level': 'WARNING', 'first_time': '2021-08-01 01:53:47,149', 'last_time': '2021-08-01 23:55:41,623', 'sample_content': ['[memory_anomalies] trigger a high memory program, start at 2021-08-01 07:44:59.839057 and lasts 600 seconds and use 1g memory', '[cpu_anomalies] trigger a parallel fast sorting program , start at 2021-08-01 18:47:52.348900 and lasts 2.9800431728363037 seconds', '[cpu_anomalies] trigger a parallel fast sorting program , start at 2021-08-01 21:19:52.653779 and lasts 2.8777551651000977 seconds', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 23:45:34.985179 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 05:28:15.047693 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 10:09:49.427582 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 18:18:29.139595 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 22:29:35.479577 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 20:40:22.812944 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 21:58:56.840885 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 09:31:07.662625 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 12:20:22.810514 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 13:19:04.278526 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 01:43:46.323905 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 10:19:55.877585 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 21:19:18.589388 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 15:20:24.950595 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 17:52:45.846587 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 02:19:32.146260 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 03:31:49.160862 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 04:49:10.816929 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 20:44:05.968949 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 16:40:05.455580 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 20:47:13.815688 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 03:43:10.516888 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 08:03:46.088980 and lasts 600 seconds and use 1g memory', '[memory_anomalies] trigger a high memory program, start at 2021-08-01 16:00:44.729007 and lasts 600 seconds and use 1g memory']}, {'cluster_id': 2, 'alert_count': 1, 'service': 'webservice1', 'level': 'WARNING', 'first_time': '2021-08-01 12:10:00,237', 'last_time': '2021-08-01 12:10:00,237', 'sample_content': ['trigger the file moving program, start with 2021-08-01 12:00:00.162585, last for 600 seconds']}, {'cluster_id': 3, 'alert_count': 664, 'service': 'mobservice2', 'level': 'WARNING', 'first_time': '2021-08-01 00:00:18,016', 'last_time': '2021-08-01 23:59:46,313', 'sample_content': ['wait for 11 seconds for follow-up operations to simulate the login failure of the QR code expired']}, {'cluster_id': 4, 'alert_count': 3, 'service': 'mobservice2', 'level': 'INFO', 'first_time': '2021-08-01 01:02:09,957', 'last_time': '2021-08-01 20:06:55,961', 'sample_content': ["request http://0.0.0.2:9387/set_key_value_into_redis and param={'keys': '0af0dbc8-f221-11eb-92bf-0242ac110003', 'value': 'oJIvjPYZ'}", "request http://0.0.0.1:9386/set_key_value_into_redis and param={'keys': 'f6fe9470-f2c0-11eb-9b33-0242ac110003', 'value': 'rJyVYctH'}", "request http://0.0.0.2:9387/set_key_value_into_redis and param={'keys': '9ae3eb24-f264-11eb-a88d-0242ac110004', 'value': 'zrFvXilR'}"]}, {'cluster_id': 5, 'alert_count': 5, 'service': 'mobservice2', 'level': 'INFO', 'first_time': '2021-08-01 03:52:48,273', 'last_time': '2021-08-01 15:50:13,627', 'sample_content': ['info e16ab40a-f238-11eb-a59d-0242ac110003:kPDTFpxO write success', 'info daf84bf0-f23d-11eb-b91a-0242ac110003:WYjcLizJ write success', 'info 98a9f2d4-f25c-11eb-a074-0242ac110004:DomOhFAT write success', 'info ead62bea-f28e-11eb-abcb-0242ac110004:bHxAGyOk write success', 'info 1a74277c-f29d-11eb-b5e0-0242ac110004:tTbvdojy write success']}]

# %%
count = 0
ss=pd.DataFrame(ls)

# %%
ss.explode("sample_content")
# Out:
#    cluster_id  alert_count      service    level               first_time  \
# 0           0           30   dbservice1     INFO  2021-08-01 03:11:19,709
# 0           0           30   dbservice1     INFO  2021-08-01 03:11:19,709
# 0           0           30   dbservice1     INFO  2021-08-01 03:11:19,709
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# 1           1           27   dbservice1  WARNING  2021-08-01 01:53:47,149
# ...

# %%
count
# Out:
# 36

# %%
for unit in ls:
    cluster_id=unit['cluster_id']
    values=unit.values()
    prompt = f"请作为SRE专家，分析以下属于同一聚类ID的日志统计信息。\
    聚类ID: [替换为具体ID，如0、1、2]\
    日志统计信息：\
    [{values}]\
    请输出结构化分析报告，只包含如下内容：\
    1. 聚类概要：告警类型、严重程度（高/中/低）、典型日志模板（动态变量用{{}}标注）\
    2. 关键特征：涉及的主要服务、日志级别、核心关键词、时间/频率模式、相关ID/参数规律\
    3. 建议与行动：监控指标、告警优化（是否需升降级）、处理建议（正常流程可降级DEBUG，异常流程给出排查步骤）、还需哪些数据确认根因"
    prompt = prompt.replace("[替换为具体ID，如0、1、2]", str(cluster_id))


    full_content = ""
    response = client.chat.completions.create(
        model=LLM_MODEL,
        messages=[{"role": "user", "content": prompt}],
        thinking={
                "type": "disabled",  # 启用深度思考模式
            },
        stream=True,
        max_tokens=2048
    )

    for chunk in response:
        content = chunk.choices[0].delta.content
        if content:
            full_content += content
            print(content, end="", flush=True)  # 实时打印
# Out:
# # SRE日志分析报告
#
# ## 1. 聚类概要
# - **告警类型**：日志上传成功通知（非告警）
# - **严重程度**：低（INFO级别）
# - **典型日志模板**：`upload {log_type} logs on {date} successfully`
#
# ## 2. 关键特征
# - **涉及的主要服务**：dbservice1
# - **日志级别**：INFO
# - **核心关键词**：upload、successfully、logs
# - **时间/频率模式**：
#   - 日志时间窗口：2021-08-01 03:11:19 - 04:00:07
#   - 内容反映：2021-07-31的日志上传情况
#   - 可能为每日凌晨定时执行的日志上传任务
# - **相关ID/参数规律**：
#   - 日志类型参数：business、trace、run_logs
#   - 日期格式：YYYY-MM-DD
#
# ## 3. 建议与行动
# - **监控指标**：
#   - dbservice1日志上传任务执行状态
#   - 日志上传成功率
#   - 定时任务执行时间窗口监控
#
# - **告警优化**：
#   - 当前为INFO级别，无需告警
#   - 可考虑为未按时出现的日志上传任务设置告警
#
# - **处理建议**：
#   - **正常流程**：此为常规操作成功通知，无需干预
#   - **异常流程排查**：
#     1. 检查网络连接稳定性
#     2. 验证存储系统可用空间
#     3. 确认日志文件完整性
#     4. 审查上传服务权限配置
#
# - **还需数据确认根因**：
#   1. 查看dbservice1完整日志序列，确认是否有上传失败记录
#   2. 检查日志上传任务的调度配置和执行历史
#   3. 分析存储系统状态，确认是否存在存储瓶颈
#   4. 验证不同类型日志文件的大小和数量变化趋势
# ### 聚类ID: 2 的日志分析报告
#
# #### 1. 聚类概要
# - **告警类型**：文件移动程序触发（File Moving Program Trigger）
# - **严重程度**：中（Medium）
# ...
