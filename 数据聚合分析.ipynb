# %%
import pandas as pd
data=pd.read_excel("降噪数据.xlsx")

# %%
data.head(1).T.to_dict()
# Out:
# {0: {'level': 'ERROR',
#   'src_ip': '0.0.0.1',
#   'service_ip': '172.17.0.3',
#   'service': 'webservice1',
#   'time_window': Timestamp('2021-07-20 03:00:00'),
#   'first_time': Timestamp('2021-07-20 03:10:01.650000'),
#   'last_time': Timestamp('2021-07-20 03:12:12.095000'),
#   'alert_count': 3,
#   'content': '[\'upload business logs on 2021-07-19 failed: (pymysql.err.OperationalError) (2003, "Can\\\'t connect to MySQL server on \\\'10.0.3.61\\\' ([Errno 111] Connection refused)")\', \'upload trace logs on 2021-07-19 failed: (pymysql.err.OperationalError) (2003, "Can\\\'t connect to MySQL server on \\\'10.0.3.61\\\' ([Errno 111] Connection refused)")\', \'upload run_logs logs on 2021-07-19 failed: (pymysql.err.OperationalError) (2003, "Can\\\'t connect to MySQL server on \\\'10.0.3.61\\\' ([Errno 111] Connection refused)")\']',
#   'trace_id_list': '[nan, nan, nan]'}}
